# %%
from agents.maze_agent import maze_agent, encontrar_celda

laberinto = [
    "S..#...",
    ".#.#.#.",
    ".#...#.",
    ".###.#.",
    ".....#E",
]
inicio = encontrar_celda(laberinto, "S")
meta = encontrar_celda(laberinto, "E")

estado_inicial = {
    "laberinto": laberinto,
    "cola": [inicio],
    "visitados": [inicio],
    "padre": {inicio: None},
    "meta": meta,
    "encontrado": False,
    "ruta": [],
}

resultado = maze_agent.invoke(estado_inicial)
print("Ruta encontrada:", resultado["ruta"])
# Out:
# Ruta encontrada: [(0, 0), (1, 0), (2, 0), (2, 1), (2, 2), (3, 2), (4, 2), (4, 1), (4, 0), (5, 0), (6, 0), (6, 1), (6, 2), (6, 3), (6, 4)]
